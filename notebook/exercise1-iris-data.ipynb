# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import mglearn
from sklearn.datasets import load_iris
plt.figure()
iris_dataset = load_iris()
iris_df = pd.DataFrame(iris_dataset['data'],columns=iris_dataset['feature_names'])
pd.scatter_matrix(iris_df,figsize=(15,15),marker='o',cmap=mglearn.cm3)
# Out:
# /home/rajeevv/virtualenv/ml_exercises/lib/python3.5/site-packages/ipykernel_launcher.py:9: FutureWarning: pandas.scatter_matrix is deprecated. Use pandas.plotting.scatter_matrix instead
#   if __name__ == '__main__':
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f324343d780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3243427e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f32433c7f60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f32433ebf60>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f324338cfd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f32433af630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f32433545f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3243375668>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f3243318780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f32433596d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f32432de048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3243280128>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f32432a4048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f32432463c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3243262898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3243205898>]],
#       dtype=object)
